# %% [markdown]
# # Lab | Matplotlib & Seaborn
#
# #### Import all the necessary libraries here:

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import math
import seaborn as sns

# %% [markdown]
# ## Challenge 1
#
# #### The data we will use in this challenge is:

# %%
x = np.arange(0,100)
y = x*2
z = x**2

# %% [markdown]
# #### Plot (x, y) and (x, z).
# There are 2 ways of doing this. Do in both ways.
#
# **Hint**: Check out the nrows, ncols and index arguments of subplots.
#
# Also, play around with the linewidth and style. Use the ones you're most happy with.

# %%
plt.plot(x,y)

# %%
plt.plot(x,z)

# %% [markdown]
# #### Use plt.subplots(nrows=1, ncols=2) to create the plot.

# %%
fig, (ax1, ax2) = plt.subplots(nrows =  1, ncols = 2)

ax1.plot(x,y)

ax2.plot(x,z)

# %% [markdown]
# #### Use your previous code but now, resize your plot.
# **Hint**: Add the figsize argument in plt.subplots().
#
# If you want, try to add a title to the plot or even axes labels. You can also play with the fontweight and fontsize of the titles and labels.

# %%
fig, (ax1, ax2) = plt.subplots(nrows =  1, ncols = 2, figsize = (15,5))

ax1.set_xlabel("X")
ax1.set_ylabel("Y")
ax1.plot(x,y)

ax2.set_xlabel("X")
ax2.set_ylabel("Z")
ax2.plot(x,z)

# %% [markdown]
# #### Now you will have to plot both $y=x^2$ and $y=e^x$ in the same plot. Create two subplots and use a normal scale in the first one and a logarithmic scale in the second one.
# **Hint**: Use `set_xscale` and `set_yscale`.

# %%
x = np.arange(0,100)
y = x**2
z = np.exp(x)

fig, (ax1, ax2) = plt.subplots(nrows =  1, ncols = 2,)

ax1.set_xlabel("X")
ax1.set_ylabel("Y")
ax1.plot(x,y)

ax2.set_xlabel("X")
ax2.set_ylabel("Z")
ax2.plot(x,z)

# %% [markdown]
# #### As a bonus challenge, try to add a legend to the plot.

# %%
# your code here

# %% [markdown]
# ## Challenge 2
# #### Import the `Fitbit2` dataset and store it in a variable called `fitbit`. You can find the dataset in Ironhack's database:
# * db: `fitbit`
# * table: `fitbit2`

# %%
df_fit = pd.read_csv('Fitbit2.csv')

# %% [markdown]
# #### From the Fitbit data, we want to visually understand:
#
# How the average number of steps change by month. Use the appropriate visualization to show the median steps by month. Is Fitbitter more active on weekend or workdays? All plots must be in the same jupyter notebook cell.
#
# **Hints**:
#
# * Use Months_encoded and Week_or Weekend columns.
# * Use matplolib.pyplot object oriented API.
# * Set your size figure to 12,4
# * Explore plt.sca
# * Explore plt.xticks
# * Save your figures in a folder called `figures` in your repo.

# %%
df_month = pd.DataFrame([df_fit.groupby(['Months_encoded']).Steps.mean().round()])
df_week = pd.DataFrame([df_fit.groupby(['Work_or_Weekend']).Steps.mean().round()])

fig, (ax1, ax2) = plt.subplots(nrows = 1, ncols = 2,sharey = True, figsize=(12,4))

ax1 = sns.barplot(data = df_month, color = 'lightblue', ax=ax1)
ax2 = sns.barplot(data = df_week, color = 'pink',ax = ax2)

plt.show()

# %% [markdown]
# #### Write a loop to plot 3 scatter plots of the following features:
#
# * Minutes Lightly Active vs Steps
# * Minutes Very Active vs Steps
# * Minutes Sedentary vs Steps

# %%
fig, (ax1, ax2, ax3) = plt.subplots(nrows = 1, ncols = 3, figsize=(18,5))

ax1 = sns.scatterplot(data = df_fit, x = 'Minutes Lightly Active', y = 'Steps', ax = ax1)
ax2 = sns.scatterplot(data = df_fit, x = 'Minutes Very Active', y = 'Steps', ax = ax2)
ax3 = sns.scatterplot(data = df_fit, x = 'Minutes Sedentary', y = 'Steps', ax = ax3)

plt.show()

# %% [markdown]
# ## Challenge 3
#
# #### Import the `titanic` dataset and store it in a variable called `titanic`. You can find the dataset in Ironhack's database:
# * db: `titanic`
# * table: `titanic`

# %%
df_tit = pd.read_csv('titanic.csv')

# %% [markdown]
# #### Explore the titanic dataset using Pandas dtypes.

# %%
df_tit.dtypes
# Out:
# PassengerId      int64
# Survived       float64
# Pclass           int64
# Name            object
# Gender          object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# #### What are your numerical variables? What are your categorical variables?
# **Hint**: Use Pandas select_dtypes.

# %%
# NUMERICAL VARIABLES
# your code here
df_tit.select_dtypes(exclude = object)
# Out:
#       PassengerId  Survived  Pclass        Age  SibSp  Parch      Fare
# 0               1       0.0       3  22.000000      1      0    7.2500
# 1               2       1.0       1  38.000000      1      0   71.2833
# 2               3       1.0       3  26.000000      0      0    7.9250
# 3               4       1.0       1  35.000000      1      0   53.1000
# 4               5       0.0       3  35.000000      0      0    8.0500
# ...           ...       ...     ...        ...    ...    ...       ...
# 1304         1305       NaN       3  29.513190      0      0    8.0500
# 1305         1306       NaN       1  39.000000      0      0  108.9000
# 1306         1307       NaN       3  38.500000      0      0    7.2500
# 1307         1308       NaN       3  29.513190      0      0    8.0500
# 1308         1309       NaN       3  25.315435      1      1   22.3583
#
# [1309 rows x 7 columns]

# %%
# CATEGORICAL VARIABLES
# your code here
df_tit.select_dtypes(include = object)
# Out:
#                                                    Name  Gender  \
# 0                               Braund, Mr. Owen Harris    male
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                                Heikkinen, Miss. Laina  female
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                              Allen, Mr. William Henry    male
# ...                                                 ...     ...
# 1304                                 Spector, Mr. Woolf    male
# 1305                       Oliva y Ocana, Dona. Fermina  female
# 1306                       Saether, Mr. Simon Sivertsen    male
# 1307                                Ware, Mr. Frederick    male
# 1308                           Peter, Master. Michael J    male
#
#                   Ticket Cabin Embarked
# 0              A/5 21171    U0        S
# 1               PC 17599   C85        C
# 2       STON/O2. 3101282    U0        S
# ...

# %% [markdown]
# #### Set the plot style to classic and the figure size to (12,6).
# **Hint**: To set the style you can use matplotlib or seaborn functions. Do some research on the matter.

# %%
import matplotlib.style
import matplotlib as mpl
mpl.style.use('default')

# %% [markdown]
# #### Use the right visulalization to show the distribution of column `Age`.

# %%
df_tit.Age.hist()
# Out:
# <Axes: >

# %% [markdown]
# #### Use subplots and plot the distribution of the `Age`  with bins equal to 10, 20 and 50.

# %%
fig, (ax1, ax2, ax3) = plt.subplots(nrows=1, ncols=3, figsize=(15,5))

ax1 = df_tit.Age.hist(bins = 10, ax = ax1)
ax2 = df_tit.Age.hist(bins = 20, ax = ax2)
ax3 = df_tit.Age.hist(bins = 50, ax = ax3)

plt.show()

# %% [markdown]
# #### How does the bin size affect your plot?

# %%
"""
your comments here
"""

# %% [markdown]
# #### Use seaborn to show the distribution of column `Age`.

# %%
sns.histplot(data = df_tit.Age)
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %% [markdown]
# #### Use the right plot to visualize column `Gender`. There are 2 ways of doing it. Do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
# Method 1 - matplotlib
# your code here
df_tit.Gender.hist()
# Out:
# <Axes: >

# %%
# Method 2 - seaborn
sns.histplot(data = df_tit.Gender)
# Out:
# <Axes: xlabel='Gender', ylabel='Count'>

# %% [markdown]
# #### Use the right plot to visualize the column `Pclass`.

# %%
# your code here
sns.histplot(data = df_tit.Pclass,)
# Out:
# <Axes: xlabel='Pclass', ylabel='Count'>

# %% [markdown]
# #### We would like to have in one single plot the summary statistics of the feature `Age`. What kind of plot would you use? Plot it.

# %%
f, ax = plt.subplots(figsize=(15,6))
ax = sns.boxplot(data = df_tit.Age)
ax.set(xlabel='Age')
sns.stripplot(data = df_tit.Age, alpha=0.5, size=7, color = 'grey', jitter = 0.2)
# Out:
# <Axes: xlabel='Age', ylabel='Age'>

# %%
"""
your comments here
"""

# %% [markdown]
# #### What does the last plot tell you about the feature `Age`?

# %%
"""
your comments here
"""

# %% [markdown]
# #### Now in addition to the summary statistics, we want to have in the same plot the distribution of `Age`. What kind of plot would you use? Plot it.

# %%
f, (ax1, ax2) = plt.subplots(nrows = 1, ncols = 2, figsize=(15,6))
ax1 = sns.boxplot(data = df_tit.Age, ax = ax1)
ax1 = sns.stripplot(data = df_tit.Age, alpha=0.5, size=7, color = 'grey', jitter = 0.2, ax = ax1)
ax2 = sns.histplot(data = df_tit.Age, ax = ax2)

# %% [markdown]
# #### What additional information does the last plot provide about feature `Age`?

# %%
"""
your comments here
"""

# %% [markdown]
# #### We suspect that there is a linear relationship between `Fare` and `Age`. Use the right plot to show the relationship between these 2 features. There are 2 ways, please do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
# Method 1 - matplotlib
# your code here

# %%
# Method 2 - seaborn
# your code here
sns.regplot(data=df_tit, x='Age', y='Fare')
plt.show()
df_tit.corr(numeric_only=True)
# Out:
#              PassengerId  Survived    Pclass       Age     SibSp     Parch  \
# PassengerId     1.000000 -0.005007 -0.038354  0.025325 -0.055224  0.008942
# Survived       -0.005007  1.000000 -0.338481 -0.065376 -0.035322  0.081629
# Pclass         -0.038354 -0.338481  1.000000 -0.425965  0.060832  0.018322
# Age             0.025325 -0.065376 -0.425965  1.000000 -0.260706 -0.145488
# SibSp          -0.055224 -0.035322  0.060832 -0.260706  1.000000  0.373587
# Parch           0.008942  0.081629  0.018322 -0.145488  0.373587  1.000000
# Fare            0.031128  0.257307 -0.558683  0.171355  0.160349  0.221635
#
#                  Fare
# PassengerId  0.031128
# Survived     0.257307
# Pclass      -0.558683
# Age          0.171355
# SibSp        0.160349
# Parch        0.221635
# Fare         1.000000

# %% [markdown]
# #### Plot the correlation matrix using seaborn.

# %%
pd.plotting.scatter_matrix(df_tit, figsize=(15,15), hist_kwds={"bins":10})
# Out:
# array([[<Axes: xlabel='PassengerId', ylabel='PassengerId'>,
#         <Axes: xlabel='Survived', ylabel='PassengerId'>,
#         <Axes: xlabel='Pclass', ylabel='PassengerId'>,
#         <Axes: xlabel='Age', ylabel='PassengerId'>,
#         <Axes: xlabel='SibSp', ylabel='PassengerId'>,
#         <Axes: xlabel='Parch', ylabel='PassengerId'>,
#         <Axes: xlabel='Fare', ylabel='PassengerId'>],
#        [<Axes: xlabel='PassengerId', ylabel='Survived'>,
#         <Axes: xlabel='Survived', ylabel='Survived'>,
#         <Axes: xlabel='Pclass', ylabel='Survived'>,
#         <Axes: xlabel='Age', ylabel='Survived'>,
#         <Axes: xlabel='SibSp', ylabel='Survived'>,
#         <Axes: xlabel='Parch', ylabel='Survived'>,
#         <Axes: xlabel='Fare', ylabel='Survived'>],
#        [<Axes: xlabel='PassengerId', ylabel='Pclass'>,
#         <Axes: xlabel='Survived', ylabel='Pclass'>,
#         <Axes: xlabel='Pclass', ylabel='Pclass'>,
#         <Axes: xlabel='Age', ylabel='Pclass'>,
# ...

# %% [markdown]
# #### What are the most correlated features?

# %%
"""
your comments here
"""

# %% [markdown]
# #### Use the most appropriate plot to display the summary statistics of `Age` depending on `Pclass`.

# %%
f, ax = plt.subplots(figsize=(15,6))
ax = sns.boxplot(data=df_tit, x='Pclass', y='Age')
sns.stripplot(data=df_tit, x='Pclass', y='Age', alpha=0.5, size=7, color = 'grey', jitter = 0.2)
plt.show()

# %% [markdown]
# #### Use seaborn to plot the distribution of `Age` based on the `Gender`.
# **Hint**: Use Facetgrid.
